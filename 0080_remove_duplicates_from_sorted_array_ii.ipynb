# %% [markdown]
# # Imports

# %%
import random

# %% [markdown]
# # Create Test Inputs

# %%
test_input      = []
current_element = 1

for i in range(15):
    current_element = current_element + random.randint(0, 1)
    test_input.append(current_element)

# %%
# test_input = [1,1,1,2,2,3]
test_input = [0,0,1,1,1,1,2,3,3]

# %%
new_test_input = test_input.copy()

# %% [markdown]
# # Implementation

# %%
def remove_duplicates_from_sorted_array(nums, new_test_input):

    i = 0
    j = 1
    k = 2
    k_increment_counter = 0
    j_k_gap = 0

    len_nums     = len(nums)
    final_length = len_nums

    if len_nums <= 2:
        return len_nums
    else:

        while (k <= (len_nums - 1)):
    
            if (nums[i] == nums[j]) and (nums[j] == nums[k]):
                # delete case
                print(f"1. Delete case: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                k += 1
                k_increment_counter += 1
                print(f"{k_increment_counter=}")
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
    
            
            elif (nums[i] == nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 1):
                print(f"2. Moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                nums[j + 1] = nums[k]
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print(f"2. Just after moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                print("*" * 120)
                print("*" * 120)
            elif (nums[i] == nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 0):
                print(f"3. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
    
            
            elif (nums[i] != nums[j]) and (nums[j] == nums[k]) and (j_k_gap == 1):
                # print(f"Error, this shouldn't have happened: {nums[i]=}, {nums[j]=}, {nums[k]=}")
                # print(f"4. Error, this shouldn't have happened: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                print(f"4. Moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                nums[j + 1] = nums[k]
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
            elif (nums[i] != nums[j]) and (nums[j] == nums[k]) and (j_k_gap == 0):
                print(f"5. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
            elif (nums[i] != nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 0):
                print(f"6. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
            elif (nums[i] != nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 1):
                # print(f"6. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                print(f"6. Moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                nums[j + 1] = nums[k]
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
            else:
                print(f"7. Error, this really shouldn't have happened: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                print(f"New nums: {nums=}")
                print("*" * 120)
                print("*" * 120)
                break
                
                
    return len_nums - k_increment_counter, nums, new_test_input

# %%
k_increment_counter, nums, new_test_input = remove_duplicates_from_sorted_array(test_input, new_test_input)
# Out:
# 3. Incrementing Counters: i=0, j=1, k=2, nums[i]=0, nums[j]=0, nums[k]=1
# New nums: nums=[0, 0, 1, 1, 1, 1, 2, 3, 3]
# ************************************************************************************************************************
# ************************************************************************************************************************
# 5. Incrementing Counters: i=1, j=2, k=3, nums[i]=0, nums[j]=1, nums[k]=1
# New nums: nums=[0, 0, 1, 1, 1, 1, 2, 3, 3]
# ************************************************************************************************************************
# ************************************************************************************************************************
# 1. Delete case: i=2, j=3, k=4, nums[i]=1, nums[j]=1, nums[k]=1
# k_increment_counter=1
# New nums: nums=[0, 0, 1, 1, 1, 1, 2, 3, 3]
# ************************************************************************************************************************
# ...

# %%
print(k_increment_counter)
# Out:
# 7

# %%
nums
# Out:
# [0, 0, 1, 1, 2, 3, 3, 3, 3]

# %%
new_test_input
# Out:
# [0, 0, 1, 1, 1, 1, 2, 3, 3]

# %%
def remove_duplicates_from_sorted_array(nums, new_test_input):

    i = 0
    j = 1
    k = 2
    k_increment_counter = 0
    j_k_gap = 0

    len_nums     = len(nums)
    final_length = len_nums

    if len_nums <= 2:
        return len_nums
    else:

        while (k <= (len_nums - 1)):
    
            if (nums[i] == nums[j]) and (nums[j] == nums[k]):
                # delete case
                # print(f"1. Delete case: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                k += 1
                k_increment_counter += 1
                # print(f"{k_increment_counter=}")
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
    
            
            elif (nums[i] == nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 1):
                # print(f"2. Moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                nums[j + 1] = nums[k]
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print(f"2. Just after moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                # print("*" * 120)
                # print("*" * 120)
            elif (nums[i] == nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 0):
                # print(f"3. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
    
            
            elif (nums[i] != nums[j]) and (nums[j] == nums[k]) and (j_k_gap == 1):
                # print(f"Error, this shouldn't have happened: {nums[i]=}, {nums[j]=}, {nums[k]=}")
                # print(f"4. Error, this shouldn't have happened: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                # print(f"4. Moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                nums[j + 1] = nums[k]
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
            elif (nums[i] != nums[j]) and (nums[j] == nums[k]) and (j_k_gap == 0):
                # print(f"5. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
            elif (nums[i] != nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 0):
                # print(f"6. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
            elif (nums[i] != nums[j]) and (nums[j] != nums[k]) and (j_k_gap == 1):
                # print(f"6. Incrementing Counters: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                # print(f"6. Moving: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                nums[j + 1] = nums[k]
                i += 1
                j += 1
                k += 1
                if (k != (j + 1)):
                    j_k_gap = 1
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
            else:
                # print(f"7. Error, this really shouldn't have happened: {i=}, {j=}, {k=}, {nums[i]=}, {nums[j]=}, {nums[k]=}")
                # print(f"New nums: {nums=}")
                # print("*" * 120)
                # print("*" * 120)
                break
                
                
    return len_nums - k_increment_counter, nums, new_test_input

# %%
# [2, 3, 4, 4, 5, 6, 6, 7, 8, 8, ]

# %%
def remove_duplicates_from_sorted_array(nums):
    
    test_input           = nums
    n_dups               = 0
    i                    = 0
    ever_duplicate       = 0
    len_test_input       = len(test_input)

    if len_test_input <= 2:
        return len_test_input, test_input

    two_previous = test_input[0]
    one_previous = test_input[1]

    i = 2
    
    while i <= (len_test_input - 1):
        
        # if i == 0:
        #     new_test_input[i] = test_input[i]
        # print(test_input[i])
        # print("**********")
        # print(f"Iteration number: {(i + 1)=}")
        # print("**********")
        
        increment_1 = one_previous  - two_previous
        increment_2 = test_input[i] - two_previous
        
        if (increment_1 == 0) and (increment_2 == 0):
            n_dups += 1
            # print(f"{n_dups=}")
            # print(f"{i + 1} index should be deleted, value {test_input[i + 1]} same as previous index value {test_input[i]}:")
            ever_duplicate = 1
        else:
            # print(f"{n_uniques=}")
            if ever_duplicate == 1:
                # print(f"{i + 1} index should be moved by {n_dups} places, value {test_input[i + 1]} different than previous index value {test_input[i]}:")
                # new_test_input[i + 1 - n_dups] = test_input[i + 1]
                
                one_previous = ab
                two_previous = ab
                
                test_input[i - n_dups] = test_input[i]
        i = i + 1
    
    return (len_test_input - n_dups), test_input

# %%
k, nums = remove_duplicates_from_sorted_array(test_input)

# %%
new_test_input
# Out:
# [1, 1, 1, 2, 2, 3]

# %%
test_input
# Out:
# [1, 1, 2, 3, 2, 3]

# %%
k
# Out:
# 12

# %%
def remove_duplicates_from_sorted_array(nums):
    
    test_input           = nums
    n_dups               = 0
    i                    = 0
    ever_duplicate       = 0
    len_test_input       = len(test_input)
    
    while i <= (len_test_input - 3):
        
        
        increment_1 = test_input[i + 1] - test_input[i]
        increment_2 = test_input[i + 2] - test_input[i]
        
        if (increment_1 == 0) and (increment_2 == 0):
            n_dups += 1
            ever_duplicate = 1
        else:
            if ever_duplicate == 1:
                test_input[i + 2 - n_dups] = test_input[i + 2]
        i = i + 1
    
    return (len_test_input - n_dups), test_input

# %%
# [4, 7, 9, 9, 10, 12, 13, 14, 14, 17]

# %%
n_dups
# Out:
# 4

# %%
k = len(test_input) - n_dups

# %%
k
# Out:
# 6

# %%
new_test_input       = [0] * (len(test_input) - 1)

# %%
new_test_input
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 0]
