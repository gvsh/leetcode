# %% [markdown]
# # 253. Meeting Rooms II

# %% [markdown]
# # Description

# %% [markdown]
# Given an array of meeting time intervals `intervals` where `intervals[i] = [starti, endi]`, return the minimum number of conference rooms required.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1

# %% [markdown]
# **Input:**
# ```
# intervals = [[0,30],[5,10],[15,20]]
# ```
# **Output:**
# ```
# 2
# ```

# %% [markdown]
# ## Example 2

# %% [markdown]
# **Input:**
# ```
# intervals = [[7,10],[2,4]]
# ```
# **Output:**
# ```
# 1
# ```

# %% [markdown]
# # Constraints

# %% [markdown]
# - $1 <= intervals.length <= 10^4$
# - $0 <= starti < endi <= 10^6$

# %%
from typing import List
import math

# %%
class Solution:
    def minMeetingRooms(self, intervals: List[List[int]]) -> int:
        
        # Wrong approach, didn't work
        # def get_intervals(intervals):

        #     intervals.sort(key=lambda x: x[1])
        #     # print(intervals)

        #     iter_end = -math.inf

        #     non_overlapping = []
        #     remaining = []
        #     counter = 0

        #     for interval in intervals:
        #         current_start, current_end = interval[0], interval[1]
        #         if current_start >= iter_end:
        #             non_overlapping.append(interval)
        #             iter_end = current_end
        #             counter += 1
        #         else:
        #             remaining.append(interval)
        #     # print(counter)
            
        #     return remaining
        
        
        
        # remaining = get_intervals(intervals)
        # counter = 1
        # print(remaining)
        # print(counter)

        # while remaining:
        #     remaining = get_intervals(remaining)
        #     counter += 1
        #     print(remaining)
        #     print(counter)
        
        # return counter


        intervals.sort()
        # print(intervals)

        room_list = [-math.inf] * len(intervals)
        # print(room_list)
        max_length = 0

        for interval in intervals:
            [start, end] = interval
            for i in range(len(room_list)):
                if start >= room_list[i]:
                    room_list[i] = end
                    # print(room_list)
                    max_length = max(max_length, i + 1)
                    # print(f"{max_length=}")
                    break

        return max_length

# %%
solution = Solution()

# %%
solution.minMeetingRooms(intervals = [[0,30],[5,10],[15,20]])
# Out:
# 2
