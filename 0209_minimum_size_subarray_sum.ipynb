# %% [markdown]
# # Problem 209. Minimum Size Subarray Sum

# %% [markdown]
# # Description

# %% [markdown]
# Given an array of positive integers `nums` and a positive integer `target`, return the minimal length of a subarray whose sum is greater than or equal to `target`. If there is no such subarray, return `0` instead.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1
# **Input:**
# `target = 7`, `nums = [2,3,1,2,4,3]`
# **Output:**
# `2`
# **Explanation:**
# The subarray `[4,3]` has the minimal length under the problem constraint.

# %% [markdown]
# ## Example 2
# **Input:**
# `target = 4`, `nums = [1,4,4]`
# **Output:**
# `1`

# %% [markdown]
# ## Example 3
# **Input:**
# `target = 11`, `nums = [1,1,1,1,1,1,1,1]`
# **Output:**
# `0`

# %% [markdown]
# # Constraints
#
# - `1 <= target <= 10^9`
# - `1 <= nums.length <= 10^5`
# - `1 <= nums[i] <= 10^4`

# %% [markdown]
# # Follow Up
#
# If you have figured out the O(n) solution, try coding another solution with a time complexity of O(n log(n)).

# %%
target = 7
nums = [2,3,1,2,4,3]
nums = [1,2,3,4,5]
target = 11
nums = [1,1,1,1,7]
target = 7

def min_subarray_sum(nums, target):

    min_length = float("inf")
    
    min_left = -1
    min_right = -1
    
    left_pointer = 0
    right_pointer = 0

    current_subarray_sum = nums[left_pointer]

    while left_pointer <= len(nums) - 1:
        
        # current_subarray_sum = current_subarray_sum + 
        
        print(f"{left_pointer=}")
        print(f"{right_pointer=}")
        print(f"{current_subarray_sum=}")
        
        if current_subarray_sum >= target:
                
            print(f"1. {left_pointer=}")
            print(f"1. {right_pointer=}")
            print(f"1. {current_subarray_sum=}")
            
            if min_length > (right_pointer - left_pointer):
                
                min_length = (right_pointer - left_pointer)
                min_left   = left_pointer
                min_right  = right_pointer
                
                print(f"1. {left_pointer=}")
                print(f"1. {right_pointer=}")
                print(f"1. {current_subarray_sum=}")
                
                left_pointer += 1
                right_pointer = left_pointer
                # current_subarray_sum = nums[left_pointer]
                
                if left_pointer <= len(nums) - 1:
                    current_subarray_sum = nums[left_pointer]
                else:
                    break
            else:
                
                left_pointer += 1
                right_pointer = left_pointer
                
                if left_pointer <= len(nums) - 1:
                    current_subarray_sum = nums[left_pointer]
                else:
                    break
                
        elif current_subarray_sum < target:
            
            print(f"2. {left_pointer=}")
            print(f"2. {right_pointer=}")
            print(f"2. {current_subarray_sum=}")
            
            if right_pointer == len(nums) - 1:
                break
            else:
                right_pointer += 1
                current_subarray_sum += nums[right_pointer]
        # else:
            
        #     # print(f"3. {left_pointer=}")
        #     # print(f"3. {right_pointer=}")
        #     # print(f"3. {current_subarray_sum=}")
            
        #     left_pointer += 1
        #     right_pointer = left_pointer

        # print("=" * 80)
            
    if min_length == float("inf"):
        return 0
    else:
        return min_length + 1

# %%
min_subarray_sum(nums, target)
# Out:
# left_pointer=0
# right_pointer=0
# current_subarray_sum=1
# 2. left_pointer=0
# 2. right_pointer=0
# 2. current_subarray_sum=1
# left_pointer=0
# right_pointer=1
# current_subarray_sum=2
# 2. left_pointer=0
# 2. right_pointer=1
# 2. current_subarray_sum=2
# left_pointer=0
# right_pointer=2
# current_subarray_sum=3
# 2. left_pointer=0
# 2. right_pointer=2
# 2. current_subarray_sum=3
# left_pointer=0
# right_pointer=3
# current_subarray_sum=4
# 2. left_pointer=0
# 2. right_pointer=3
# 2. current_subarray_sum=4
# left_pointer=0
# right_pointer=4
# current_subarray_sum=11
# 1. left_pointer=0
# 1. right_pointer=4
# 1. current_subarray_sum=11
# 1. left_pointer=0
# 1. right_pointer=4
# 1. current_subarray_sum=11
# left_pointer=1
# right_pointer=1
# current_subarray_sum=1
# 2. left_pointer=1
# 2. right_pointer=1
# 2. current_subarray_sum=1
# left_pointer=1
# right_pointer=2
# current_subarray_sum=2
# 2. left_pointer=1
# 2. right_pointer=2
# 2. current_subarray_sum=2
# left_pointer=1
# ...

# %%
target = 7
nums = [2,3,1,2,4,3]
nums = [1,2,3,4,5]
target = 11
nums = [1,1,1,1,7]
target = 7

def min_subarray_sum(nums, target):

    min_length = float("inf")
    
    min_left = -1
    min_right = -1
    
    left_pointer = 0
    right_pointer = 0
    
    while left_pointer <= len(nums) - 1:
        
        current_subarray_sum = sum(nums[left_pointer: right_pointer + 1])
        
        print(f"{left_pointer=}")
        print(f"{right_pointer=}")
        print(f"{current_subarray_sum=}")
        
        if current_subarray_sum >= target:
                
            print(f"1. {left_pointer=}")
            print(f"1. {right_pointer=}")
            print(f"1. {current_subarray_sum=}")
            
            if min_length > (right_pointer - left_pointer):
                
                min_length = (right_pointer - left_pointer)
                min_left   = left_pointer
                min_right  = right_pointer
                
                print(f"1. {left_pointer=}")
                print(f"1. {right_pointer=}")
                print(f"1. {current_subarray_sum=}")
                
                left_pointer += 1
                right_pointer = left_pointer
            else:
                
                left_pointer += 1
                right_pointer = left_pointer
                
        elif current_subarray_sum < target:
            
            print(f"2. {left_pointer=}")
            print(f"2. {right_pointer=}")
            print(f"2. {current_subarray_sum=}")
            
            if right_pointer == len(nums) - 1:
                break
            else:
                right_pointer += 1
        # else:
            
        #     # print(f"3. {left_pointer=}")
        #     # print(f"3. {right_pointer=}")
        #     # print(f"3. {current_subarray_sum=}")
            
        #     left_pointer += 1
        #     right_pointer = left_pointer

        # print("=" * 80)
            
    return min_length + 1

# %%
target = 7
nums = [2,3,1,2,4,3]
nums = [1,2,3,4,5]
target = 11

def min_subarray_sum(nums, target):

    min_length = float("inf")
    
    min_left = -1
    min_right = -1
    
    left_pointer = 0
    right_pointer = 0
    
    while left_pointer <= len(nums) - 1:
        
        current_subarray_sum = sum(nums[left_pointer: right_pointer + 1])
        
        # print(f"{left_pointer=}")
        # print(f"{right_pointer=}")
        # print(f"{current_subarray_sum=}")
        
        if current_subarray_sum == target:
                
            # print(f"1. {left_pointer=}")
            # print(f"1. {right_pointer=}")
            # print(f"1. {current_subarray_sum=}")
            
            if min_length > (right_pointer - left_pointer):
                
                min_length = (right_pointer - left_pointer)
                min_left   = left_pointer
                min_right  = right_pointer
                
                # print(f"1. {left_pointer=}")
                # print(f"1. {right_pointer=}")
                # print(f"1. {current_subarray_sum=}")
                
                left_pointer += 1
            else:
                
                left_pointer += 1
                
        elif current_subarray_sum < target:
            
            # print(f"2. {left_pointer=}")
            # print(f"2. {right_pointer=}")
            # print(f"2. {current_subarray_sum=}")
            
            if right_pointer == len(nums) - 1:
                break
            else:
                right_pointer += 1
        else:
            
            # print(f"3. {left_pointer=}")
            # print(f"3. {right_pointer=}")
            # print(f"3. {current_subarray_sum=}")
            
            left_pointer += 1
            right_pointer = left_pointer

        # print("=" * 80)
            
    return min_length + 1

# %%
min_subarray_sum(nums, target)
# Out:
# 2
