# %% [markdown]
# # Problem 11: Container With Most Water
#
# ## Description
# You are given an integer array `height` of length `n`. There are `n` vertical lines drawn such that the two endpoints of the `i-th` line are `(i, 0)` and `(i, height[i])`.
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# **Note:** You may not slant the container.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1
# **Input:**
# `height = [1,8,6,2,5,4,8,3,7]`
# **Output:**
# `49`
# **Explanation:**
# The above vertical lines are represented by array `[1,8,6,2,5,4,8,3,7]`. In this case, the max area of water (blue section) the container can contain is `49`.

# %% [markdown]
# ## Example 2

# %% [markdown]
# **Input:**
# `height = [1,1]`
# **Output:**
# `1`

# %% [markdown]
# # Constraints

# %% [markdown]
# - `n == height.length`
# - `2 <= n <= 10^5`
# - `0 <= height[i] <= 10^4`

# %% [markdown]
# # Approach

# %% [markdown]
# 1. Keep `left` and `right` pointers at two extreme ends.
# 2. Measure volume.
# 3. Move them inwards only if you can increase the height of water level.
# 4. Compare with previous maximum and update if you get new max.

# %% [markdown]
# # Implementation

# %%
height = [1,8,6,2,5,4,8,3,7]

# %% [markdown]
# # Solution Attempt 2025-08-24

# %%
left = 0
right = len(height) - 1

left_value = height[left]
right_value = height[right]

max_volume = min(height[left], height[right]) * (right - left)

while left < right:
    
    if height[left] >= height[right]:
        right -= 1
    else:
        left += 1

    volume = min(height[left], height[right]) * (right - left)
    
    max_volume = max(max_volume, volume)
    print(left, right, volume, max_volume)
# Out:
# 1 8 49 49
# 1 7 18 49
# 1 6 40 49
# 1 5 16 49
# 1 4 15 49
# 1 3 4 49
# 1 2 6 49
# 1 1 0 49

# %%
max_volume
# Out:
# 8

# %%
left
# Out:
# 0

# %%
right
# Out:
# 8

# %%
right_value
# Out:
# 7

# %%
left         = 0
right        = len(height) - 1
max_volume   = 0

water_height = min(height[left], height[right])
c_length     = right - left
volume       = water_height * c_length
max_volume   = max(max_volume, volume)

# %%
def max_water(height):
        
    left         = 0
    right        = len(height) - 1
    max_volume   = 0
    
    water_height = min(height[left], height[right])
    c_length     = right - left
    volume       = water_height * c_length
    max_volume   = max(max_volume, volume)
    
    while left < right:
    
        # Try to increment left if left is shorter
    
        if height[left] <= height[right]:
            left += 1
        else:
            right -= 1
        
        water_height = min(height[left], height[right])
        c_length     = right - left
        volume       = water_height * c_length
        max_volume   = max(max_volume, volume)
        # Try to decrement right if right is shorter
    
        # Get current water level.

    return max_volume
