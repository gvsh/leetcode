# %% [markdown]
# # 394. Decode String

# %% [markdown]
# # Description

# %% [markdown]
# Given an encoded string, return its decoded string.
#
# The encoding rule is: `k[encoded_string]`, where the `encoded_string` inside the square brackets is repeated exactly `k` times. Note that `k` is guaranteed to be a positive integer.
#
# You may assume that the input string is always valid; there are no extra white spaces, square brackets are well-formed, etc. Furthermore, you may assume that the original data does not contain any digits and that digits are only for those repeat numbers, `k`. For example, there will not be input like `3a` or `2[4]`.
#
# The test cases are generated so that the length of the output will never exceed `10^5`.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1

# %% [markdown]
# **Input:** `s = "3[a]2[bc]"`
#
# **Output:** `"aaabcbc"`

# %% [markdown]
# ## Example 2

# %% [markdown]
# **Input:** `s = "3[a2[c]]"`
#
# **Output:** `"accaccacc"`

# %% [markdown]
# ## Example 3

# %% [markdown]
# **Input:** `s = "2[abc]3[cd]ef"`
#
# **Output:** `"abcabccdcdcdef"`

# %% [markdown]
# # Constraints

# %% [markdown]
# - `1 <= s.length <= 30`
# - `s` consists of lowercase English letters, digits, and square brackets `'[]'`.
# - `s` is guaranteed to be a valid input.
# - All the integers in `s` are in the range `[1, 300]`.

# %%
s = "3[a8[c]]"

# %%
s = "3[a8[c]]"
input_s = list(s)

# %%
most_recent_left_index = -1

for i, ch in enumerate(input_s):
    if ch == "[":
        most_recent_left_index = i
    if ch == "]":
        print(input_s[most_recent_left_index: i + 1])
# Out:
# ['[', 'c', ']']
# ['[', 'c', ']', ']']

# %% [markdown]
# ## Notes
#
# 1.

# %%
output_string = ""

# %%
def pop_stack_until_start_brace(i, stack):

    start_i = i
    ch_pop = stack.pop()
    i -= 1
    
    while ch_pop != "[":
        ch_pop = stack.pop()
        i -= 1
        
        return i + 1, start_i, stack
    
def repeat_char(input_char,

# %%
s = "4[a3[c2[b]]]"
input_s = list(s)

stack = []
stack.append(input_s[0])

for i in range(1 , len(input_s)):
    
    print(i)
    ch = input_s[i]
    
    if ch == "]":
        
        start_index, end_index, stack = pop_stack_until_start_brace(i, stack)
        
        print(f"{start_index=}")
        print(f"{end_index=}")
        print(f"{stack=}")
        
        print(input_s[start_index : end_index])
        print(input_s[start_index - 2])

        repeated_string = input_s[start_index : end_index] * int(input_s[start_index - 2])
        
        print(f"{repeated_string=}")

        output_string = output_string + "".join(repeated_string)
        print(f"{output_string=}")
    
    else:    
        stack.append(ch)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# start_index=8
# end_index=9
# stack=['4', '[', 'a', '3', '[', 'c', '2']
# ['b']
# 2
# repeated_string=['b', 'b']
# output_string='bb'
# 10
# start_index=9
# end_index=10
# stack=['4', '[', 'a', '3', '[']
# [']']
# [
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 19
#      15 print(input_s[start_index : end_index])
#      17 print(input_s[start_index - 2])
# ---> 19 repeated_string = input_s[start_index : end_index] * int(input_s[start_index - 2])
#      20 print(f"{repeated_string=}")
#      22 output_string = output_string + "".join(repeated_string)
#
# ValueError: invalid literal for int() with base 10: '['

# %%
l1 = list(range(10))

# %%
l1.pop()
# Out:
# 9

# %%
n = l1.pop()

# %%
n
# Out:
# 8

# %%
aaaa

# %%
stack = []

# %%
stack.append(3)

# %%
stack.append("[")

# %%
stack
# Out:
# [3, '[']

# %%
stack.append("a")

# %%
stack.append("2")
