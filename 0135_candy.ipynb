# %% [markdown]
# # 135. Candy

# %% [markdown]
# **Hard**

# %% [markdown]
# ---

# %% [markdown]
# # Problem
#
# There are `n` children standing in a line. Each child is assigned a rating value given in the integer array `ratings`.
#
# You are giving candies to these children subjected to the following requirements:
#
# 1. Each child must have at least one candy.
# 2. Children with a higher rating get more candies than their neighbors.
#
# Return the minimum number of candies you need to have to distribute the candies to the children.
#
# ---

# %% [markdown]
# # Examples
# ## Example 1
#
# **Input:**
# `ratings = [1,0,2]`
#
# **Output:**
# `5`
#
# **Explanation:**
# You can allocate to the first, second, and third child with `2`, `1`, and `2` candies respectively.
#
# ---
#
# ## Example 2
#
# **Input:**
# `ratings = [1,2,2]`
#
# **Output:**
# `4`
#
# **Explanation:**
# You can allocate to the first, second, and third child with `1`, `2`, and `1` candies respectively. The third child gets `1` candy because it satisfies the above two conditions.

# %% [markdown]
# ---
#
# # Constraints
#
# - `n == ratings.length`
# - $1 \leq n \leq 2 \times 10^4$
# - $0 \leq ratings[i] \leq 2 \times 10^4$

# %% [markdown]
# # Solution

# %% [markdown]
# ## Thinking Process
#
# 1. Let's construct a few examples

# %%
import random

# %%
import random

list_length = random.randint(5, 20)

ratings = [random.randint(0, 7) for _ in range(list_length)]

print("Random List:", ratings)
print("Index  List:", list(range(list_length)))
# Out:
# Random List: [4, 5, 2, 2, 5, 5, 1]
# Index  List: [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# For the list above:
# Minimum index is 6 with value 1.
# Give 1 to index 6.
# index 5 has neighbours as 5 and 1.
# It should get at least 2.
#
# Give 1 to
# 1. Start with minimum rating indices. They should get 1.
# 2. Their neighbours should get 2.
# 3. If those neighbours have a neigh

# %% [markdown]
# 1. Let x[i] be the candies that have to be given to index i.
# 2. All x[i] >= 1.
# 3. if nums[i - 1] < nums[i], then x[i - 1] < x[i]
# 4. minimize(sum(x[i]))
