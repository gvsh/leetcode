# %% [markdown]
# # Problem 77: Combinations

# %% [markdown]
# # Description
# Given two integers `n` and `k`, return all possible combinations of `k` numbers chosen from the range `[1, n]`.
#
# You may return the answer in any order.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1
# **Input:**
# `n = 4, k = 2`
# **Output:**
# `[[1,2],[1,3],[1,4],[2,3],[2,4],[3,4]]`
# **Explanation:**
# There are $ {4 \choose 2} = 6$ total combinations.
# Note that combinations are unordered, i.e., `[1,2]` and `[2,1]` are considered to be the same combination.

# %% [markdown]
# ## Example 2
# **Input:**
# `n = 1, k = 1`
# **Output:**
# `[[1]]`
# **Explanation:**
# There is ${1 \choose 1}  = 1$ total combination.

# %% [markdown]
# # Constraints
# - $ 1 \leq n \leq 20 $
# - $ 1 \leq k \leq n $

# %%
from typing import List, Optional
import math

# %%
class Solution:
    def combine(self, n: int, k: int) -> List[List[int]]:


        ans = []

        def is_a_solution(a, n, k):
            return len(a) == k

        def process_solution(a, n, k):
            ans.append(a[::])
            # print(a)

        def construct_candidates(a, n, k):
            complete_set    = set(n)
            already_present = set(a)

            max_a = max(a) if len(a) > 0 else 0

            candidates = complete_set - already_present

            candidates = [x for x in candidates if x > max_a]

            return candidates

        def make_move(a, n, k):
            pass
        
        def unmake_move(a, n):
            pass

        def backtrack(a, n, k):

            if is_a_solution(a, n, k):
                process_solution(a, n, k)
            else:

                candidates = construct_candidates(a, n, k)

                for candidate in candidates:

                    # make_move(a, n)

                    backtrack(a + [candidate], n, k)

                    # unmake_move(a, n)

        init_n = list(range(1, n + 1))
        
        backtrack([], init_n, k)

        return ans

# %%
solution = Solution()
solution.combine(5, 3)
# Out:
# [[1, 2, 3],
#  [1, 2, 4],
#  [1, 2, 5],
#  [1, 3, 4],
#  [1, 3, 5],
#  [1, 4, 5],
#  [2, 3, 4],
#  [2, 3, 5],
#  [2, 4, 5],
#  [3, 4, 5]]
