# %% [markdown]
# # Problem 278: First Bad Version

# %% [markdown]
# # Description
#
# You are a product manager and currently leading a team to develop a new product. Unfortunately, the latest version of your product fails the quality check. Since each version is developed based on the previous version, all the versions after a bad version are also bad.
#
# Suppose you have `n` versions `[1, 2, ..., n]` and you want to find out the first bad one, which causes all the following ones to be bad.
#
# You are given an API `bool isBadVersion(version)` which returns whether a version is bad. Implement a function to find the first bad version. You should minimize the number of calls to the API.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1
#
# **Input:**
#
# n = 5, bad = 4
#
#
# **Output:**
#
# 4
#
#
# **Explanation:**
# - call `isBadVersion(3)` -> `false`
# - call `isBadVersion(5)` -> `true`
# - call `isBadVersion(4)` -> `true`
# Thus, 4 is the first bad version.

# %% [markdown]
# ## Example 2
#
# **Input:**
#
# n = 1, bad = 1
#
#
# **Output:**
#
# 1
#
#
# **Explanation:**
# Since `n = 1` and `bad = 1`, the only version is bad.

# %% [markdown]
# # Constraints
#
# - `1 <= bad <= n <= 2^31 - 1`

# %% [markdown]
# # Follow Up
#
# How can you reduce the number of calls to the API `isBadVersion` while still determining the first bad version efficiently?

# %%
from collections import Counter

# %%
s = "abcd"
t = "abcde"

# %%
sc = Counter(s)
tc = Counter(t)

# %%
sc
# Out:
# Counter({'a': 1, 'b': 1, 'c': 1, 'd': 1})

# %%
list((tc - sc).keys())[0]
# Out:
# 'e'

# %%
nums = [0, 1, 0, 3, 5, 12]


zero_count = 0

for i in range(len(nums)):

    # print(f"Second condition: {((len(nums) - 1) - zero_count)}")
    # print(f"{i=}")
    # print("=" * 10)
    
    if nums[i] == 0:
        zero_count += 1
        # print("Case 1")
        # print(f"{zero_count=}")
    elif (nums[i] != 0):
        nums[i - zero_count] = nums[i]
        # print("Case 2")
        # print(f"{i=}")
        # print(f"{nums[i]=}")
        # print(f"{nums[i - zero_count]=}")
        # print(f"{zero_count=}")
    # else:
    #     print("Case 3")
    #     nums[i] == 0
    # print("=" * 80)
    # print("=" * 80)
    # print("=" * 80)
# Out:
# Second condition: 5
# i=0
# ...
# Case 1
# zero_count=1
# ...
# Second condition: 4
# i=1
# ...
# Case 2
# i=1
# nums[i]=1
# nums[i - zero_count]=1
# zero_count=1
# ...
# Second condition: 4
# i=2
# ...
# Case 1
# zero_count=2
# ...
# Second condition: 3
# i=3
# ...
# Case 2
# i=3
# nums[i]=3
# nums[i - zero_count]=3
# zero_count=2
# ...
# Second condition: 3
# i=4
# ...
# Case 2
# i=4
# nums[i]=5
# nums[i - zero_count]=5
# zero_count=2
# ...
# Second condition: 3
# i=5
# ...
# Case 2
# i=5
# nums[i]=12
# nums[i - zero_count]=12
# zero_count=2
# ...

# %%
nums
# Out:
# [1, 3, 5, 12, 5, 12]
