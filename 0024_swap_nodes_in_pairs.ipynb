# %% [markdown]
# # Problem 24: Swap Nodes in Pairs
#
# # Description
# Given a linked list, swap every two adjacent nodes and return its head. You must solve the problem without modifying the values in the list's nodes (i.e., only nodes themselves may be changed).
#
# # Examples
#
# ## Example 1
# **Input:**
# `head = [1,2,3,4]`
# **Output:**
# `[2,1,4,3]`
#
# ## Example 2
# **Input:**
# `head = []`
# **Output:**
# `[]`
#
# ## Example 3
# **Input:**
# `head = [1]`
# **Output:**
# `[1]`
#
# ## Example 4
# **Input:**
# `head = [1,2,3]`
# **Output:**
# `[2,1,3]`
#
# # Constraints
# - The number of nodes in the list is in the range `[0, 100]`.
# - `0 <= Node.val <= 100`

# %% [markdown]
# # Submitted

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def swapPairs(self, head: Optional[ListNode]) -> Optional[ListNode]:
                

        def print_list(l1):

            i = 0
            
            while l1:
                print(f"Node {i + 1} has value: {l1.val}")
                i += 1
                l1 = l1.next

        dummy = ListNode(0)
        dummy.next = head

        first = head
        rest_of_list = None

        prev = dummy

        while first and first.next:
            
            second       = first.next
            rest_of_list = second.next

            second.next  = first
            first.next   = rest_of_list

            prev.next    = second

            prev  = first
            first = first.next

            # print_list(dummy.next)

            # print("=" * 80)
            # print("=" * 80)
            # print("=" * 80)







            # prev.next = second

            # print(f"{prev.val=}")

            # if rest_of_list:
            #     print(f"{rest_of_list.val=}")
            
            # second.next = first
            # print(f"{second.val=}")
            # first.next = rest_of_list
            # # print(f"{first.next.val=}")


            # first = rest_of_list
            # prev  = 
            # if first:
            #     print(f"{first.val=}")

            # print("=" * 80)
            # if prev:
            #     print(f"{prev.val=}")
            # if prev.next:
            #     print(f"{prev.next.val=}")
            # if second:
            #     print(f"{second.val=}")
            # if second.next:
            #     print(f"{second.next.val=}")
            # if first:
            #     print(f"{first.val=}")


            # print("=" * 80)
            # print("=" * 80)
            # print("=" * 80)

        return dummy.next
