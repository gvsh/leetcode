# %% [markdown]
# # Library Installations

# %%
# !pip install python-lorem

# %%
# !apt install libgraphviz-dev
# !pip install pygraphviz

# %%
# !apt-get install graphviz
# !pip install graphviz

# %% [markdown]
# # Google Colab Specific Setup

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# # Imports

# %%
# import lorem
# import random

# from pathlib     import Path
# from collections import Counter

# from datetime import date
# from datetime import time
# from datetime import datetime

# %% [markdown]
# # Problem

# %% [markdown]
# # 392 Is Subsequence

# %% [markdown]
# Given two strings `s` and `t`, return true if `s` is a subsequence of `t`, or `false` otherwise.
#
# A subsequence of a string is a new string that is formed from the original string by deleting some (can be none) of the characters without disturbing the relative positions of the remaining characters. (i.e., `"ace"` is a subsequence of `"abcde"` while `"aec"` is not).

# %% [markdown]
# # Examples

# %% [markdown]
# **Example 1:**
#
# ```
# s = "abc", t = "ahbgdc"
# ```
# Output:
# ```
# true
# ```
#
#
#
#
# **Example 2:**
#
# Input:
# ```
# x = "axc", t = "ahbgdc"
# ```
# Output:
# ```
# false
# ```

# %% [markdown]
# # Constraints

# %% [markdown]
# `0 <= s.length <= 100`
# `0 <= t.length <= 10^4`
# `s` and `t` consist of only lowercase English letters.

# %% [markdown]
# # Solution

# %%
import random
from random import choice
from typing import List

# %%
import string

print(string.ascii_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
ascii_letters = string.ascii_letters

# %%
def get_random_lower_case_word(lower, upper):

    s_length = random.randint(lower, upper)
    s        = "".join([choice(ascii_letters[:7]) for _ in range(s_length)])

    return s.lower()
    # return ("abcd" + s.lower())

# %%
def get_random_s_and_t(s_length_max, t_length_max):

    random_s = get_random_lower_case_word(0, s_length_max)
    s_length = len(random_s)
    random_t = get_random_lower_case_word(s_length, t_length_max)

    return random_s, random_t

# %%
random_s, random_t = get_random_s_and_t(7, 20)
print(random_s)
print(random_t)
# Out:
# cafgadc
# eageebcegdagba

# %%
def create_test_suite(test_suite_n_elements):

    test_suite = [get_random_s_and_t(7, 20) for _ in range(test_suite_n_elements)]

    return test_suite

# %%
test_suite = create_test_suite(20)

# %%
test_suite
# Out:
# [('', 'gb'),
#  ('dc', 'bggagagfgcdb'),
#  ('egaec', 'aegagfdcdedg'),
#  ('dccab', 'fbddfabedebd'),
#  ('db', 'gfe'),
#  ('degeg', 'efdfabfdggdfbd'),
#  ('adgeeg', 'bfagebface'),
#  ('dg', 'caedfaaae'),
#  ('bdd', 'fdgee'),
#  ('abge', 'ddcffce'),
#  ('gdab', 'efbdcefbggdfafebcdd'),
#  ('gd', 'ebcecgffe'),
#  ('cgfe', 'gacgbcagfcgabffefdcb'),
#  ('dddfbdd', 'dacacfgeabcaafea'),
#  ('afce', 'dcfccegcgb'),
#  ('cgefee', 'agfgce'),
#  ('aabf', 'gaddafbbdbdcbagcgd'),
#  ('bgadaa', 'fgcebfccdbacgae'),
#  ('', ''),
#  ('bfgca', 'cfacaccbebceddabdf')]

# %%
from typing import List
import pdb

class Solution:
    def isSubsequence(self, s: str, t: str) -> bool:
        return True

# %%
def string_to_hash_map(input_s, input_t):

    t_hash_map = {}

    for i, c in enumerate(input_t):
        if c in input_s:
            if c in t_hash_map:
                t_hash_map[c].append(i)
            else:
                t_hash_map[c] = [i]

    for i, c in enumerate(input_s):
        if c not in input_t:
            t_hash_map = {}
    # for k, v in t_hash_map.items():
    #     print(k, v)
    # print("***************")

    return t_hash_map

# %%
all_info_object = [(s, t, string_to_hash_map(s, t)) for s, t in test_suite]

# %%
all_info_object
# Out:
# [('', 'gb', {}),
#  ('dc', 'bggagagfgcdb', {'c': [9], 'd': [10]}),
#  ('egaec',
#   'aegagfdcdedg',
#   {'a': [0, 3], 'e': [1, 9], 'g': [2, 4, 11], 'c': [7]}),
#  ('dccab', 'fbddfabedebd', {}),
#  ('db', 'gfe', {}),
#  ('degeg', 'efdfabfdggdfbd', {'e': [0], 'd': [2, 7, 10, 13], 'g': [8, 9]}),
#  ('adgeeg', 'bfagebface', {}),
#  ('dg', 'caedfaaae', {}),
#  ('bdd', 'fdgee', {}),
#  ('abge', 'ddcffce', {}),
#  ('gdab',
#   'efbdcefbggdfafebcdd',
#   {'b': [2, 7, 15], 'd': [3, 10, 17, 18], 'g': [8, 9], 'a': [12]}),
#  ('gd', 'ebcecgffe', {}),
#  ('cgfe',
#   'gacgbcagfcgabffefdcb',
#   {'g': [0, 3, 7, 10], 'c': [2, 5, 9, 18], 'f': [8, 13, 14, 16], 'e': [15]}),
#  ('dddfbdd', 'dacacfgeabcaafea', {'d': [0], 'f': [5, 13], 'b': [9]}),
#  ('afce', 'dcfccegcgb', {}),
#  ('cgefee', 'agfgce', {'g': [1, 3], 'f': [2], 'c': [4], 'e': [5]}),
#  ('aabf',
#   'gaddafbbdbdcbagcgd',
#   {'a': [1, 4, 13], 'f': [5], 'b': [6, 7, 9, 12]}),
#  ('bgadaa',
#   'fgcebfccdbacgae',
# ...

# %%
all_info_object[0][1]
# Out:
# 'abcgdegcebebfed'

# %%
t_current_string = all_info_object[0][1]

# %%
for i, (s, t, t_hash_map) in enumerate(all_info_object):
    print("*********")
    print(i, s, t)
    print("*********")
    if t_hash_map:
        for j, (current_char, next_char) in enumerate(zip(s, s[1:])):
            print(j, current_char, next_char)
            print(t_hash_map[current_char])
            print(t_hash_map[next_char])
    print("*********")
    print("*********")
    print("@@@@@@@@@")
# Out:
# *********
# 0 ddg ceaefacgc
# *********
# *********
# *********
# @@@@@@@@@
# *********
# 1 cbegafe dfaafgedfdcaegbgdba
# *********
# 0 c b
# [10]
# [14, 17]
# 1 b e
# [14, 17]
# [6, 12]
# 2 e g
# [6, 12]
# [5, 13, 15]
# 3 g a
# [5, 13, 15]
# [2, 3, 11, 18]
# 4 a f
# [2, 3, 11, 18]
# [1, 4, 8]
# 5 f e
# [1, 4, 8]
# [6, 12]
# *********
# *********
# @@@@@@@@@
# *********
# 2  dfcgffddcbfaaga
# *********
# *********
# *********
# @@@@@@@@@
# *********
# 3 ceddd ecfbeaadeggcagddffe
# *********
# 0 c e
# [1, 11]
# [0, 4, 8, 18]
# 1 e d
# [0, 4, 8, 18]
# [7, 14, 15]
# 2 d d
# [7, 14, 15]
# [7, 14, 15]
# 3 d d
# [7, 14, 15]
# [7, 14, 15]
# *********
# *********
# @@@@@@@@@
# *********
# 4  fgcagc
# *********
# *********
# *********
# @@@@@@@@@
# *********
# 5 ca fgaggaeeagg
# *********
# *********
# *********
# @@@@@@@@@
# *********
# 6 g ggfeaadbgb
# *********
# *********
# *********
# @@@@@@@@@
# *********
# 7 cdc ecageeaecdecfdb
# *********
# 0 c d
# [1, 8, 11]
# [9, 13]
# 1 d c
# ...

# %%
for i, x in enumerate(zip())

# %%
from collections import defaultdict

# %%
letter_indices_table = defaultdict(list)

# %%
letter_indices_table['a']
# Out:
# []

# %%
from bisect import bisect_left

# %%
solution_object = Solution()
string_outputs      = [solution_object.isSubsequence(s, t) for s, t in test_suite]
# string_outputs      = solution_object.longestCommonPrefix(["a"])

print(f"{string_outputs=}")
# Out:
# k [0]
# c [1]
# r [2]
# ***************
# @@@@@@@@@@@@@@
# m [0, 12, 24]
# t [1, 16, 23]
# u [2, 21]
# o [3]
# i [4]
# s [5]
# e [6]
# a [7, 13]
# x [8, 10, 14]
# d [9, 22, 25]
# h [11]
# j [15, 35, 37]
# r [17, 33]
# k [18, 38]
# f [19]
# l [20, 30, 34]
# v [26, 32]
# q [27]
# n [28]
# b [29]
# c [31, 36]
# ***************
# --------------
# m [0]
# y [1]
# c [2]
# b [3]
# ***************
# @@@@@@@@@@@@@@
# t [0, 2, 30]
# a [1, 47]
# b [3, 4, 39]
# d [5, 11, 15, 27]
# c [6, 32]
# n [7, 9, 34, 40]
# o [8, 14]
# j [10]
# i [12, 13, 18, 19, 33, 37]
# h [16, 17, 21, 41]
# q [20]
# e [22]
# v [23, 42]
# p [24, 25]
# l [26, 36, 38]
# k [28]
# w [29, 45]
# g [31]
# u [35]
# r [43]
# y [44, 48]
# z [46]
# ***************
# --------------
# q [0]
# u [1, 3]
# p [2]
# n [4]
# ***************
# @@@@@@@@@@@@@@
# e [0, 14, 23]
# r [1, 24, 33]
# b [2, 6, 26]
# z [3, 17]
# g [4, 30]
# k [5, 11]
# m [7]
# o [8]
# j [9]
# u [10]
# h [12]
# w [13]
# l [15, 16]
# c [18, 19, 21]
# i [20]
# v [22]
# ...

# %%
random_word_string
# Out:
# ['abcdrigvnydudsompmae',
#  'abcdtdugujlkgdjxyefl',
#  'abcdejsyrbfzb',
#  'abcdbbzpoiwzlwqytb',
#  'abcdqbrjavgwrrvzilrrwedq',
#  'abcdhmitlrddzkbijctxmlfa',
#  'abcdbvnzfimykl',
#  'abcdt',
#  'abcdshvote',
#  'abcdccccbsmcxiwouwmxbada']

# %%
from typing import List
import pdb
class Solution:
    def longestCommonPrefix(self, strs: List[str]) -> str:

        longest_common_prefix   = []
        current_char_to_compare = ""
        current_index           = -1
        exit_loop               = 0

        # pdb.set_trace()
        if len(strs) > 0:
            while (exit_loop < 1):
                current_index += 1
                if (current_index <= (len(strs[0]) - 1)):
                    current_char_to_compare = strs[0][current_index]
                else:
                    exit_loop = 1

                exit_for_loop = 0
                for str in strs[1:]:
                    if (current_index > (len(str) - 1)) or (str[current_index] != current_char_to_compare):
                        exit_for_loop = 1
                        break

                if (exit_for_loop == 0) and ((exit_loop == 0)):
                    longest_common_prefix.append(current_char_to_compare)
                else:
                    exit_loop = 1


        return "".join(longest_common_prefix)

# %%
solution_object = Solution()
string_outputs      = solution_object.longestCommonPrefix(random_word_string)
# string_outputs      = solution_object.longestCommonPrefix(["a"])

print(f"{string_outputs=}")
# Out:
# string_outputs='abcd'
