# %% [markdown]
# # 120. Triangle
#
# ## Description
#
# Given a triangle array, return the minimum path sum from top to bottom.
#
# For each step, you may move to an adjacent number of the row below. More formally, if you are on index `i` on the current row, you may move to either index `i` or `i + 1` on the next row.
#
# ## Examples
#
# ### Example 1
#
# **Input:**
#
# `triangle = [[2],[3,4],[6,5,7],[4,1,8,3]]`
#
#
# **Output:**
#
# `11`
#
#
# **Explanation:**
# The triangle looks like:
#
# `   2`
# `  3 4`
# ` 6 5 7`
# `4 1 8 3`
#
# The minimum path sum from top to bottom is `2 + 3 + 5 + 1 = 11`.
#
# ---
#
# ### Example 2
#
# **Input:**
#
# `triangle = [[-10]]`
#
#
# **Output:**
#
# `-10`
#
#
# ## Constraints
#
# - `1 <= triangle.length <= 200`
# - `triangle[0].length == 1`
# - `triangle[i].length == triangle[i - 1].length + 1`
# - `-10^4 <= triangle[i][j] <= 10^4`
#
# ## Follow Up
#
# Could you do this using only `O(n)` extra space, where `n` is the total number of rows in the triangle?

# %% [markdown]
# # Notes

# %% [markdown]
# 1. Let `min_path_row_col[i, j]` denote the minimum path sum at row `i`, column `j` of the triangle.
# 2. Then, `min_path_row_col[i, j]` is the minimum of its two parents.
# 3. For the last row, if we have `calculated min_path_row_col[i, j]` for each element, then we can take its minimum to get the row minimum.

# %% [markdown]
# # Algorithm

# %% [markdown]
# 1. As per the above notes, the algorithm then is:
# 2. Start from the top row, calculate `min_path_row_col[i, j]` for each element of the row.
# 3. Stop at last row.
# 4. Calculate the minimum over the last row.

# %%
from typing import List, Optional

# %%
triangle = [[2],[3,4],[6,5,7],[4,1,8,3]]

# %%
def get_index_of_parents(i, j):
    
    parents = []
    
    if (j - 1) >= 0:
        parents.append((i - 1, j - 1))

    if j < i:
        parents.append((i - 1, j))

    return parents

# %%
get_index_of_parents(3, 1)
# Out:
# [(2, 0), (2, 1)]

# %%
get_index_of_parents(2, 2)
# Out:
# [(1, 1)]

# %%
get_index_of_parents(3, 3)
# Out:
# [(2, 2)]

# %%
def get_path_sum_of_parents(i, j, min_path_row_col, triangle):

    parent_indices = get_index_of_parents(i, j)
    parent_values = []
    
    for current_index in parent_indices:
        parent_values.append(min_path_row_col[current_index] + triangle[i][j])

    print(f"parent_values for {i}, {j} are {parent_values=}")

    return min(parent_values)

# %%
def minimumTotal(triangle: List[List[int]]) -> int:
    

    # min_path_row_col[i][j] = i_j

    min_path_row_col = {}
    
    min_path_row_col[0, 0] = triangle[0][0]
    i = 1
    j = 0
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 1
    j = 1
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 2
    j = 0
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 2
    j = 1
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 2
    j = 2
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    
    i = 3
    j = 0
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 3
    j = 1
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 3
    j = 2
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)
    i = 3
    j = 3
    min_path_row_col[i, j] = get_path_sum_of_parents(i, j, min_path_row_col, triangle)

    print(min_path_row_col)
    # min_path_row_col[1, 0] = min(

# %%
minimumTotal(triangle)
# Out:
# parent_values for 1, 0 are parent_values=[5]
# parent_values for 1, 1 are parent_values=[6]
# parent_values for 2, 0 are parent_values=[11]
# parent_values for 2, 1 are parent_values=[10, 11]
# parent_values for 2, 2 are parent_values=[13]
# parent_values for 3, 0 are parent_values=[15]
# parent_values for 3, 1 are parent_values=[12, 11]
# parent_values for 3, 2 are parent_values=[18, 21]
# parent_values for 3, 3 are parent_values=[16]
# {(0, 0): 2, (1, 0): 5, (1, 1): 6, (2, 0): 11, (2, 1): 10, (2, 2): 13, (3, 0): 15, (3, 1): 11, (3, 2): 18, (3, 3): 16}

# %%
min_path_row_col = {}

min_path_row_col[0, 0] = triangle[0][0]

# %%
min_path_row_col
# Out:
# {(0, 0): 2}

# %%
min_path_row_col
# Out:
# {(0, 0): 2}

# %%
    parents = []
    
    if (j - 1) >= 0:
        parents.append((i - 1, j - 1))
        
    parents.append((i - 1, j))
