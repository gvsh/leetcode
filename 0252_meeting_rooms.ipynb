# %% [markdown]
# # 252. Meeting Rooms

# %% [markdown]
# # Description

# %% [markdown]
# Given an array of meeting time intervals where `intervals[i] = [start_i, end_i]`, determine if a person could attend all meetings.
#
# A person can attend all meetings if none of the meetings overlap. Your task is to return `true` if the person can attend all meetings, otherwise return `false`.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1

# %% [markdown]
# **Input:**
# ```
# intervals = [[0,30],[5,10],[15,20]]
# ```
# **Output:**
# ```
# false
# ```

# %% [markdown]
# ## Example 2

# %% [markdown]
# **Input:**
# ```
# intervals = [[7,10],[2,4]]
# ```
# **Output:**
# ```
# true
# ```

# %% [markdown]
# # Constraints

# %% [markdown]
# - 0 <= intervals.length <= 10⁴
# - intervals[i].length == 2
# - 0 <= start_i < end_i <= 10⁶

# %%
from typing import List
import math

# %%
class Solution:
    def canAttendMeetings(self, intervals: List[List[int]]) -> bool:
        
        intervals.sort(key=lambda x: x[1])

        previous_end = -math.inf

        for interval in intervals:
            [start, end] = interval
            if start < previous_end:
                return False
            else:
                previous_end = end

        return True

# %%
solution = Solution()

# %%
solution.canAttendMeetings(intervals = [[0,30],[5,10],[15,20]])
# Out:
# False
