# %% [markdown]
# # Problem 6: Zigzag Conversion
#
# ## Description
# The string `"PAYPALISHIRING"` is written in a zigzag pattern on a given number of rows like this:
# (You may want to display this pattern in a fixed font for better legibility)
#
# P A H N A P L S I I G Y I R
#
#
# And then read line by line: `"PAHNAPLSIIGYIR"`
#
# Write the code that will take a string and make this conversion given a number of rows:
#
# ```
# string convert(string s, int numRows);
# ```
#
# # Examples
# ## Example 1
#
# Input:
# s = "PAYPALISHIRING", numRows = 3
# Output:
# "PAHNAPLSIIGYIR"
#
# ## Example 2
#
# Input:
# s = "PAYPALISHIRING", numRows = 4
# Output:
# "PINALSIGYAHRPI"
# Explanation:
#
# P     I    N
# A   L S  I G
# Y A   H R
# P     I
#
# ## Example 3
#
# Input:
# s = "A", numRows = 1
# Output:
# "A"
#
# # Constraints
#
#     1 <= s.length <= 1000
#     s consists of English letters (lower-case and upper-case), ',', and '.'.
#     1 <= numRows <= 1000

# %%
class Solution:
    def convert(self, s: str, numRows: int) -> str:
        # 
        # 3 rows: 2 col, 4 chars per block (3 + 1)
        # 
        # 4 rows: 3 col, 6 chars per block (4 + 2)
        # 
        # 5 rows: 4 col, 8 chars per block (5 + 3)
        # n rows: (n - 1) columns, (2n - 2) characters)
        # First n char in first column
        # next (n + n - 2 char):
        # n + 1 in second last row (n - 1) row
        # n + 2 in n - 2 row
        # n + (n - 2) in n - (n - 2)
        # After (2n - 2) chars, 
        # m = 2n - 2
        # m1 = n
        # m2 = n - 2

# %%
# m * 1
# m * 2
input_string = "PAYPALISHIRING_DO_ZIGZAGCONVERSION"
n = 5
m = 2 * n - 2

m1 = n
m2 = n - 2
n_blocks = (34 // m) + 1
n_col = n_blocks * (n - 1)

zz_row = ["" for _ in range(n_col)]
zz_m   = [zz_row[:] for _ in range(n)]

# %%
zz_row = ["" for _ in range(n_col)]

# %%
zz_row
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
zz_m = [zz_row[:] for _ in range(n)]

# %%
zz_m
# Out:
# [['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '']]

# %%
zz_m = []

for _ in range(n_col):
    zz_row = []
    for _ in range(n):
        zz_m.a

# %%
n = 5

# %%
input_string = "PAYPALISHIRING_DO_ZIGZAGCONVERSION"

# %%
m = 2 * n - 2

# %%
m
# Out:
# 8

# %%
m1 = n

# %%
m2 = n - 2

# %%
(m1, m2)
# Out:
# (5, 3)

# %%
len(input_string)
# Out:
# 34

# %%
n_blocks = (34 // m) + 1

# %%
n_blocks
# Out:
# 5

# %%
n_col = n_blocks * (n - 1)

# %%
n_col
# Out:
# 20

# %%
zz_row = [""] * n_col

# %%
zz_m = [zz_row] * n

# %%
from pprint import pprint
print(zz_m)
# Out:
# [['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']]

# %%
# m * 1
# m * 2
input_string = "PAYPALISHIRING_DO_ZIGZAGCONVERSION"
n = 5
m = 2 * n - 2

m1 = n
m2 = n - 2
n_blocks = (34 // m) + 1
n_col = n_blocks * (n - 1)

zz_row = ["" for _ in range(n_col)]
zz_m   = [zz_row[:] for _ in range(n)]

i_to_block = {}
v_flag = 0
d_flag = 0

for i, char in enumerate(input_string):
    
    block_number = i // (2 * n - 2)
    block_pos    = (i % (2 * n - 2)) + 1
    if block_pos <= n:
        v_flag = 1
        d_flag = 0
        row_number = block_pos - 1
        col_number = (block_number * (n - 1))
    else:
        d_flag = 1
        v_flag = 0
        row_number = n - (block_pos - n) - 1
        col_number = ((block_number * (n - 1)) + 1) + (block_pos - n) - 1
    zz_m[row_number][col_number] = char
    # print(f"{i=}, {block_number=}, {block_pos=}, {row_number=}, {col_number=}, {char=}")
    print(f"{row_number=}, {col_number=}, {char=}")
    block_number
# Out:
# row_number=0, col_number=0, char='P'
# row_number=1, col_number=0, char='A'
# row_number=2, col_number=0, char='Y'
# row_number=3, col_number=0, char='P'
# row_number=4, col_number=0, char='A'
# row_number=3, col_number=1, char='L'
# row_number=2, col_number=2, char='I'
# row_number=1, col_number=3, char='S'
# row_number=0, col_number=4, char='H'
# row_number=1, col_number=4, char='I'
# row_number=2, col_number=4, char='R'
# row_number=3, col_number=4, char='I'
# row_number=4, col_number=4, char='N'
# row_number=3, col_number=5, char='G'
# row_number=2, col_number=6, char='_'
# row_number=1, col_number=7, char='D'
# row_number=0, col_number=8, char='O'
# row_number=1, col_number=8, char='_'
# row_number=2, col_number=8, char='Z'
# row_number=3, col_number=8, char='I'
# row_number=4, col_number=8, char='G'
# row_number=3, col_number=9, char='Z'
# row_number=2, col_number=10, char='A'
# row_number=1, col_number=11, char='G'
# row_number=0, col_number=12, char='C'
# row_number=1, col_number=12, char='O'
# row_number=2, col_number=12, char='N'
# row_number=3, col_number=12, char='V'
# row_number=4, col_number=12, char='E'
# row_number=3, col_number=13, char='R'
# row_number=2, col_number=14, char='S'
# row_number=1, col_number=15, char='I'
# row_number=0, col_number=16, char='O'
# row_number=1, col_number=16, char='N'

# %%
# zz_m
out_str = ""

for row in zz_m:
    for char in row:
        if char != "":
            out_str += char

# %%
zz_m[0][0]
# Out:
# 'P'

# %%
out_str
# Out:
# 'PHOCOASID_GOINYIR_ZANSPLIGIZVRANGE'

# %%
# PINALSIGYAHRPI

# %%
i_to_block = {}
v_flag = 0
d_flag = 0

for i, char in enumerate(input_string):
    
    block_number = i // (2 * n - 2)
    block_pos    = (i % (2 * n - 2)) + 1
    if block_pos <= n:
        v_flag = 1
        d_flag = 0
        row_number = block_pos - 1
        col_number = (block_number * (n - 1))
    else:
        d_flag = 1
        v_flag = 0
        row_number = n - (block_pos - n) - 1
        col_number = ((block_number * (n - 1)) + 1) + (block_pos - n) - 1
    zz_m[row_number][col_number] = char
    # print(f"{i=}, {block_number=}, {block_pos=}, {row_number=}, {col_number=}, {char=}")
    print(f"{row_number=}, {col_number=}, {char=}")
    block_number

# %%
# m * 1
# m * 2
input_string = "PAYPALISHIRING"
n = 4
m = 2 * n - 2

m1 = n
m2 = n - 2
n_blocks = (34 // m) + 1
n_col = n_blocks * (n - 1)

zz_row = ["" for _ in range(n_col)]
zz_m   = [zz_row[:] for _ in range(n)]

i_to_block = {}
v_flag = 0
d_flag = 0

for i, char in enumerate(input_string):
    
    block_number = i // (2 * n - 2)
    block_pos    = (i % (2 * n - 2)) + 1
    if block_pos <= n:
        v_flag = 1
        d_flag = 0
        row_number = block_pos - 1
        col_number = (block_number * (n - 1))
    else:
        d_flag = 1
        v_flag = 0
        row_number = n - (block_pos - n) - 1
        col_number = ((block_number * (n - 1)) + 1) + (block_pos - n) - 1
    zz_m[row_number][col_number] = char
    # print(f"{i=}, {block_number=}, {block_pos=}, {row_number=}, {col_number=}, {char=}")
    print(f"{row_number=}, {col_number=}, {char=}")
    block_number

# zz_m
out_str = ""

for row in zz_m:
    for char in row:
        if char != "":
            out_str += char

print(out_str)
# Out:
# row_number=0, col_number=0, char='P'
# row_number=1, col_number=0, char='A'
# row_number=2, col_number=0, char='Y'
# row_number=3, col_number=0, char='P'
# row_number=2, col_number=1, char='A'
# row_number=1, col_number=2, char='L'
# row_number=0, col_number=3, char='I'
# row_number=1, col_number=3, char='S'
# row_number=2, col_number=3, char='H'
# row_number=3, col_number=3, char='I'
# row_number=2, col_number=4, char='R'
# row_number=1, col_number=5, char='I'
# row_number=0, col_number=6, char='N'
# row_number=1, col_number=6, char='G'
# PINALSIGYAHRPI

# %%
# PINALSIGYAHRPI

# %% [markdown]
# # Final Submitted

# %%
class Solution:
    def convert(self, s: str, numRows: int) -> str:
        
        n            = numRows
        input_string = s
        len_s        = len(input_string)

        if n == 1:
            return s
        

        m        = 2 * n - 2

        m1       = n
        m2       = n - 2
        n_blocks = (len_s // m) + 1
        n_col    = n_blocks * (n - 1)

        zz_row   = ["" for _ in range(n_col + 1)]
        zz_m     = [zz_row[:] for _ in range(n)]


        for i, char in enumerate(input_string):
            
            block_number = i // (2 * n - 2)
            block_pos    = (i % (2 * n - 2)) + 1
            if block_pos <= n:
                row_number = block_pos - 1
                col_number = (block_number * (n - 1))
            else:
                row_number = n - (block_pos - n) - 1
                col_number = ((block_number * (n - 1)) + 1) + (block_pos - n) - 1
            zz_m[row_number][col_number] = char
            # print(f"{row_number=}, {col_number=}, {char=}")

        # zz_m
        out_str = ""

        for row in zz_m:
            for char in row:
                if char != "":
                    out_str += char

        return out_str
