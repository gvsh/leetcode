# %% [markdown]
# # Problem 283. Move Zeroes

# %% [markdown]
# ## Description

# %% [markdown]
# Given an integer array `nums`, move all `0`'s to the end of it while maintaining the relative order of the non-zero elements.
#
# Note that you must do this **in-place** without making a copy of the array.

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Example 1

# %% [markdown]
# **Input:**
# `nums = [0,1,0,3,12]`
# **Output:**
# `[1,3,12,0,0]`

# %% [markdown]
# ### Example 2

# %% [markdown]
# **Input:**
# `nums = [0]`
# **Output:**
# `[0]`

# %% [markdown]
# ## Constraints

# %% [markdown]
# - $ 1 \leq nums.length \leq 10^4 $
# - $ -2^{31} \leq nums[i] \leq 2^{31} - 1 $

# %% [markdown]
# ## Follow Up

# %% [markdown]
# Could you minimize the total number of operations done?

# %%
import random

# %%
random.choice([1, 3, 4, 5])
# Out:
# 1

# %%
random.randint(0, 10)
# Out:
# 9

# %%
random.random()
# Out:
# 0.32616750470248856

# %%
nums = [random.randint(0, 3) for x in range(10)]

# %%
nums
# Out:
# [0, 1, 0, 2, 1, 1, 0, 2, 1, 0]

# %%
write = -1

if nums[0] == 0:
    write = 0
else:
    i += 1
if nums[1] == 0:
    write += 1


for i in range(len(nums)):
    if nums

# %% [markdown]
# # Notes

# %% [markdown]
# 1. Keep track of the next index where the next non-zero element needs to be written
# 2. Scan through the list.
# 3. When you encounter a zero while scanning, move forward.
# 4. When you encounter a non-zero while scanning:
# ```
# nums[write] = nums[i]
# nums[i] = 0
# Write needs to be moved now

# %%
import random
from random import choice
from typing import List, Optional

# from pydantic import BaseModel

# %%
class Solution:
    def moveZeroes(self, nums: List[int]) -> None:
        """
        Do not return anything, modify nums in-place instead.
        """
                
        zero_count = 0

        for i in range(len(nums)):

            if nums[i] == 0:
                zero_count += 1
            elif (nums[i] != 0):
                nums[i - zero_count] = nums[i]

        for i in range(len(nums) - 1, len(nums) - zero_count - 1 , -1):
            nums[i] = 0

# %%
solution_object = Solution()

# %%
nums = [0, 1, 0, 3, 12]

solution_object.moveZeroes(nums)

# %%
nums
# Out:
# [1, 3, 12, 0, 0]
