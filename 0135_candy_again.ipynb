# %% [markdown]
# # Problem 135. Candy
#
# ## Description
# There are `n` children standing in a line. Each child is assigned a rating value given in the integer array `ratings`.
#
# You need to distribute candies to these children according to the following rules:
# 1. Each child must receive at least one candy.
# 2. Children with a higher rating must receive more candies than their immediate neighbors.
#
# Return the minimum number of candies required to satisfy the above conditions.
#
# ## Examples
#
# ### Example 1
# **Input:**
# `ratings = [1,0,2]`
# **Output:**
# `5`
# **Explanation:**
# - The first child receives 2 candies.
# - The second child receives 1 candy.
# - The third child receives 2 candies.
#
# ### Example 2
# **Input:**
# `ratings = [1,2,2]`
# **Output:**
# `4`
# **Explanation:**
# - The first child receives 1 candy.
# - The second child receives 2 candies.
# - The third child receives 1 candy because it satisfies the conditions.
#
# ## Constraints
# - `n == ratings.length`
# - `1 <= n <= 2 * 10^4`
# - `0 <= ratings[i] <= 2 * 10^4`

# %% [markdown]
# # Approach

# %% [markdown]
# 1. Left array would store the number of candies required at each position if each student just needs to have more candies than the left student.
# 2.

# %%
ratings = [1, 2, 3, 4]
ratings = [4, 3, 2, 1]

# %%
n = len(ratings)

left_candies  = [1] * n
right_candies = [1] * n
candies       = [1] * n

# %%
for i in range(1, len(ratings)):
    if ratings[i - 1] < ratings[i]:
        left_candies[i] = left_candies[i - 1] + 1
        
left_candies
# Out:
# [1, 1, 1, 1]

# %%
for i in range(len(ratings) - 1, 0, -1):
    if ratings[i] < ratings[i - 1]:
        right_candies[i - 1] = right_candies[i] + 1
    print(i)
# Out:
# 3
# 2
# 1

# %%
right_candies
# Out:
# [4, 3, 2, 1]

# %%
for i in range(n):
    candies[i] = max(left_candies[i], right_candies[i])

# %%
candies
# Out:
# [4, 3, 2, 1]

# %%
n = len(ratings)

left_candies  = [1] * n
right_candies = [1] * n
candies       = [1] * n

for i in range(1, len(ratings)):
    if ratings[i - 1] < ratings[i]:
        left_candies[i] = left_candies[i - 1] + 1

for i in range(len(ratings) - 1, 0, -1):
    if ratings[i] < ratings[i - 1]:
        right_candies[i - 1] = right_candies[i] + 1
    print(i)

for i in range(n):
    candies[i] = max(left_candies[i], right_candies[i])

# %%
x1, x2 = "IV"

# %%
x1 + x2
# Out:
# 'IV'
