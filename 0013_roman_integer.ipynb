# %%
s = "MCMXCIV"
# Output: 1994

# %%
roman_numeral_map = {
    "M": 1000,
    "D": 500,
    "C": 100,
    "L": 50,
    "X": 10,
    "V": 5,
    "I": 1
}

roman_compound_map = {
    "IV": 4,
    "IX": 9,
    "XL": 40,
    "XC": 90,
    "CD": 400,
    "CM": 900
}

# %%
compound_indices = []
value = 0

for x in roman_compound_map.keys():
    # print(x)
    x1, x2 = x

    for i, (ch1, ch2) in enumerate(zip(s, s[1:])):
        if (x1, x2) == (ch1, ch2):
            print(i, x, roman_compound_map[x])
            value += roman_compound_map[x]
            compound_indices.append(i)
            compound_indices.append(i + 1)
# Out:
# 5 IV 4
# 3 XC 90
# 1 CM 900

# %%
compound_indices
# Out:
# [5, 6, 3, 4, 1, 2]

# %%
for i in range(len(s)):
    if i not in compound_indices:
        print(roman_numeral_map[s[i]])
        value += roman_numeral_map[s[i]]
# Out:
# 1000

# %%
value
# Out:
# 1994

# %%
x1, x2 = "Iv"

# %%
x1
# Out:
# 'I'

# %%
roman_numeral_map = {
    "M": 1000,
    "D": 500,
    "C": 100,
    "L": 50,
    "X": 10,
    "V": 5,
    "I": 1
}

roman_compound_map = {
    "IV": 4,
    "IX": 9,
    "XL": 40,
    "XC": 90,
    "CD": 400,
    "CM": 900
}

compound_indices = []
value = 0

for x in roman_compound_map.keys():
    # print(x)
    x1, x2 = x

    for i, (ch1, ch2) in enumerate(zip(s, s[1:])):
        if (x1, x2) == (ch1, ch2):
            # print(i, x, roman_compound_map[x])
            value += roman_compound_map[x]
            compound_indices.append(i)
            compound_indices.append(i + 1)

for i in range(len(s)):
    if i not in compound_indices:
        # print(roman_numeral_map[s[i]])
        value += roman_numeral_map[s[i]]

# %%
value
# Out:
# 1994

# %%
roman_numeral_map = {
    "M": 1000,
    "D": 500,
    "C": 100,
    "L": 50,
    "X": 10,
    "V": 5,
    "I": 1
}

roman_compound_map = {
    "IV": 4,
    "IX": 9,
    "XL": 40,
    "XC": 90,
    "CD": 400,
    "CM": 900
}

compound_indices = []
value = 0


for i, (ch1, ch2) in enumerate(zip(s, s[1:])):
    x = ch1 + ch2
    if x in roman_compound_map.keys(): 
        print(i, x, roman_compound_map[x])           
        value += roman_compound_map[x]
        compound_indices.append(i)
        compound_indices.append(i + 1)

for i in range(len(s)):
    if i not in compound_indices:
        value += roman_numeral_map[s[i]]
# Out:
# 1 CM 900
# 3 XC 90
# 5 IV 4

# %%
value
# Out:
# 1994
