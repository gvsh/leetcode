# %% [markdown]
# # Problem 9: Palindrome Number

# %% [markdown]
# # Description
# Given an integer `x`, return `true` if `x` is a palindrome, and `false` otherwise.
#
# A palindrome is a number that reads the same backward as forward.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1
# **Input:**
# x = 121
# **Output:**
# true
# **Explanation:**
# 121 reads as 121 from left to right and from right to left.

# %% [markdown]
# ## Example 2
# **Input:**
# x = -121
# **Output:**
# false
# **Explanation:**
# From left to right, it reads -121. From right to left, it becomes 121-. Therefore, it is not a palindrome.

# %% [markdown]
# ## Example 3
# **Input:**
# x = 10
# **Output:**
# false
# **Explanation:**
# Reads 01 from right to left. Therefore, it is not a palindrome.

# %% [markdown]
# # Constraints
# - $ -2^{31} \leq x \leq 2^{31} - 1 $

# %% [markdown]
# # Follow Up

# %% [markdown]
# Could you solve it without converting the integer to a string?

# %%
x = 12344321

counter = 0
x_remaining = x
x_reversed = 0

while x_remaining > x_reversed:
    print(f"{counter=}")
    print(f"{x_remaining=}")
    
    new_digit   = x_remaining % 10
    
    x_reversed  = x_reversed * 10 + new_digit
    counter     += 1
    x_remaining = x_remaining // 10
    
    print(f"{x_reversed=}")
    print(f"{new_digit=}")
    print("=" * 80)

print(f"{x_reversed=}")

print(x_reversed // 10)
print(f"{x_remaining=}")
# Out:
# counter=0
# x_remaining=12344321
# x_reversed=1
# new_digit=1
# ...
# counter=1
# x_remaining=1234432
# x_reversed=12
# new_digit=2
# ...
# counter=2
# x_remaining=123443
# x_reversed=123
# new_digit=3
# ...
# counter=3
# x_remaining=12344
# x_reversed=1234
# new_digit=4
# ...
# x_reversed=1234
# 123
# x_remaining=1234

# %%
x_remaining
# Out:
# 1234

# %%
x_reversed
# Out:
# 12345

# %%
# if x < 0 or (x % 10 == 0 and x != 0):
#     return False
x = 12344321

revertedNumber = 0
while x > revertedNumber:
    print(f"{revertedNumber=}")
    revertedNumber = revertedNumber * 10 + x % 10
    print(f"{revertedNumber=}")
    x //= 10
    print(f"{x=}")
    print("=" * 80)

# When the length is an odd number, we can get rid of the middle digit by revertedNumber//10
# For example when the input is 12321, at the end of the while loop we get x = 12, revertedNumber = 123,
# since the middle digit doesn't matter in palidrome(it will always equal to itself), we can simply get rid of it.
print(x == revertedNumber or x == revertedNumber // 10)
# Out:
# revertedNumber=0
# revertedNumber=1
# x=1234432
# ...
# revertedNumber=1
# revertedNumber=12
# x=123443
# ...
# revertedNumber=12
# revertedNumber=123
# x=12344
# ...
# revertedNumber=123
# revertedNumber=1234
# x=1234
# ...
# True

# %%
revertedNumber
# Out:
# 1234

# %%
x
# Out:
# 1234
