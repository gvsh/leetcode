# %% [markdown]
# # 452. Minimum Number of Arrows to Burst Balloons

# %% [markdown]
# # Description
# There are some spherical balloons taped onto a flat wall that represents the XY-plane. The balloons are represented as a 2D integer array `points` where `points[i] = [xstart, xend]` denotes a balloon whose horizontal diameter stretches between `xstart` and `xend`. You do not know the exact y-coordinates of the balloons.
#
# Arrows can be shot directly vertically (in the positive y-direction) from different points along the x-axis. A balloon with `xstart` and `xend` is burst by an arrow shot at `x` if `xstart <= x <= xend`. There is no limit to the number of arrows that can be shot. A shot arrow keeps traveling up infinitely, bursting any balloons in its path.
#
# Given the array `points`, return the **minimum number of arrows** that must be shot to burst all balloons.

# %% [markdown]
# # Examples

# %% [markdown]
# ## Example 1

# %% [markdown]
# **Input:**
# `points = [[10,16],[2,8],[1,6],[7,12]]`
# **Output:**
# `2`
# **Explanation:**
# The balloons can be burst by 2 arrows:
# - Shoot an arrow at `x = 6`, bursting the balloons `[2,8]` and `[1,6]`.
# - Shoot an arrow at `x = 11`, bursting the balloons `[10,16]` and `[7,12]`.
#
# ---

# %% [markdown]
# ## Example 2

# %% [markdown]
# **Input:**
# `points = [[1,2],[3,4],[5,6],[7,8]]`
# **Output:**
# `4`
# **Explanation:**
# One arrow needs to be shot for each balloon, for a total of 4 arrows.
#
# ---

# %% [markdown]
# ## Example 3
# **Input:**
# `points = [[1,2],[2,3],[3,4],[4,5]]`
# **Output:**
# `2`
# **Explanation:**
# The balloons can be burst by 2 arrows:
# - Shoot an arrow at `x = 2`, bursting the balloons `[1,2]` and `[2,3]`.
# - Shoot an arrow at `x = 4`, bursting the balloons `[3,4]` and `[4,5]`.

# %% [markdown]
# # Constraints
# - `1 <= points.length <= 10^5`
# - `points[i].length == 2`
# - `-2^31 <= xstart < xend <= 2^31 - 1`

# %%
points = [[10,16],[2,8],[1,6],[7,12]]

# %%
points.sort(key= lambda x: x[1])

# %%
points
# Out:
# [[1, 6], [2, 8], [7, 12], [10, 16]]

# %%
points = [[10,16],[2,8],[1,6],[7,12]]

# sort by the end values
# if there's an overlap, don't increment the arrow count
# otherwise increment arrow count and update the new first end
points.sort(key= lambda x: x[1])

arrows = 1
first_end = points[0][1]

for point in points:
    if point[0] <= first_end:
        # Overlap Case as the current point's starting value is less than the end value
        # first_end = point[1]
        print(f"{point=}")
        print(f"{first_end=}")
        print(f"{arrows=}")
    else:
        arrows += 1
        first_end = point[1]

    print("=" * 80)
# Out:
# point=[1, 6]
# first_end=6
# arrows=1
# ================================================================================
# point=[2, 8]
# first_end=6
# arrows=1
# ================================================================================
# ================================================================================
# point=[10, 16]
# first_end=12
# arrows=2
# ================================================================================

# %%
arrows
# Out:
# 2

# %%
# New Solution

# %%
class Solution:
    def findMinArrowShots(self, points: List[List[int]]) -> int:

        points.sort()

        print(points)
        
        group_start = -math.inf
        group_end   = math.inf

        count = 1

        for interval in points:
            [start, end] = interval
            if start <= group_end:
                group_end = min(end, group_end)
            else:
                count += 1
                group_start = start
                group_end   = end
        
        # count += 1
        
        return count
