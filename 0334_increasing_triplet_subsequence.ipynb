# %% [markdown]
# # Problem 334: Increasing Triplet Subsequence
#
# # Description
# Given an integer array `nums`, return `true` if there exists a triple of indices `(i, j, k)` such that `i < j < k` and `nums[i] < nums[j] < nums[k]`. If no such indices exist, return `false`.
#
# # Examples
#
# ## Example 1
# **Input:**
# `nums = [1, 2, 3, 4, 5]`
# **Output:**
# `true`
# **Explanation:**
# Any triplet where `i < j < k` is valid.
#
# ## Example 2
# **Input:**
# `nums = [5, 4, 3, 2, 1]`
# **Output:**
# `false`
# **Explanation:**
# No triplet exists.
#
# ## Example 3
# **Input:**
# `nums = [2, 1, 5, 0, 4, 6]`
# **Output:**
# `true`
# **Explanation:**
# The triplet `(3, 4, 5)` is valid because `nums[3] == 0 < nums[4] == 4 < nums[5] == 6`.
#
# # Constraints
# - `1 <= nums.length <= 5 * 10^5`
# - `-2^31 <= nums[i] <= 2^31 - 1`
#
# # Follow Up
# Could you implement a solution that runs in `O(n)` time complexity and `O(1)` space complexity?

# %% [markdown]
# # Solution Attempt
# ## 2025-08-22

# %% [markdown]
# ### Notes

# %% [markdown]
# 1. The trick is to maintain the minimum seen so far.
# 2. The second minimum seen so far.
# 3. If then, any number is found greater than the second, we have found a triplet.

# %%
import math

first = math.inf

# %%
first
# Out:
# inf

# %%
second = math.inf

# %%
def is_triplet_sequence_present(nums)
    
    for i in range(len(nums)):
    
        if nums[i] < first:
            first = nums[i]
        elif nums[i] < second:
            second = nums[i]
        else:
            return True
    
    return False

# %%
from typing import List

# %%
class Solution:
    def increasingTriplet(self, nums: List[int]) -> bool:
        
        first_num  = float("inf")
        second_num = float("inf")
        
        for n in nums:
            if n <= first_num:
                first_num = n
            elif n <= second_num:
                second_num = n
            else:
                return True
        return False

# %%
solution = Solution()

# %%
solution.increasingTriplet([1, 2, 3, 4, 5, 6, 2, 3])
# Out:
# True

# %%
from typing import List

# %%
def increasingTriplet(nums: List[int]) -> bool:
    if len(nums) < 3:
        return False

    smallest = float('inf')
    smallest_with_smaller_preceding = float('inf')

    for num in nums:
        if num <= smallest:
            smallest = num
            print(f"Smallest {smallest}")
        elif num <= smallest_with_smaller_preceding:
            smallest_with_smaller_preceding = num
            print(f"Smallest, Second smallest: {smallest}, {smallest_with_smaller_preceding}")
        else:
            print(f"Smallest, Second smallest, Current Num: {smallest}, {smallest_with_smaller_preceding}, {num}")
            return True
        print("*" * 80)

    return False

# %%
increasingTriplet([5, 6, 2, 5, 4, 4, 2, 2, 3, 1, 0])
# Out:
# Smallest 5
# ********************************************************************************
# Smallest, Second smallest: 5, 6
# ********************************************************************************
# Smallest 2
# ********************************************************************************
# Smallest, Second smallest: 2, 5
# ********************************************************************************
# Smallest, Second smallest: 2, 4
# ********************************************************************************
# Smallest, Second smallest: 2, 4
# ********************************************************************************
# Smallest 2
# ********************************************************************************
# Smallest 2
# ********************************************************************************
# Smallest, Second smallest: 2, 3
# ********************************************************************************
# Smallest 2
# ...
