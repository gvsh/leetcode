# %% [markdown]
# # Library Installations

# %%
# !pip install python-lorem

# %%
# !apt install libgraphviz-dev
# !pip install pygraphviz

# %%
# !apt-get install graphviz
# !pip install graphviz

# %% [markdown]
# # Google Colab Specific Setup

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %% [markdown]
# # Imports

# %%
# import lorem
# import random

# from pathlib     import Path
# from collections import Counter

# from datetime import date
# from datetime import time
# from datetime import datetime

# %% [markdown]
# # Problem

# %% [markdown]
# # 13 Roman to Integer

# %% [markdown]
# Roman numerals are represented by seven different symbols: `I`, `V`, `X`, `L`, `C`, `D` and `M`.
#
# Symbol |       Value |
# -------|--------------
# I    |         1|
# V   |          5
# X    |         10
# L     |        50
# C      |       100
# D       |      500
# M        |     1000
#
# For example, `2` is written as `II` in Roman numeral, just two ones added together.
# `12` is written as `XII`, which is simply `X + II`. The number `27` is written as `XXVII`, which is `XX + V + II`.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not `IIII`. Instead, the number four is written as `IV`. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as `IX`. There are six instances where subtraction is used:
#
# - `I` can be placed before `V` (5) and `X` (10) to make `4` and `9`.
# - `X` can be placed before `L` (50) and `C` (100) to make `40` and `90`.
# - `C` can be placed before `D` (500) and `M` (1000) to make `400` and `900`.
#
# Given a roman numeral, convert it to an integer.

# %% [markdown]
# # Examples

# %% [markdown]
# **Example 1:**
#
# Input:
# ```
# haystack = "sadbutsad", needle = "sad"
# ```
# Output:
# ```
# 0
# ```
# Explanation:
# "sad" occurs at index 0 and 6.
# The first occurrence is at index 0, so we return 0.
#
#
#
# **Example 2:**
#
# Input:
# ```
# haystack = "leetcode", needle = "leeto"
# ```
# Output:
# ```
# -1
# ```
# Explanation:
# "leeto" did not occur in "leetcode", so we return -1.

# %% [markdown]
# # Constraints

# %% [markdown]
# `1 <= haystack.length, needle.length <= 104`
# `haystack` and `needle` consist of only lowercase English characters.

# %% [markdown]
# # Solution

# %%
import random
from random import choice
from typing import List

# %%
import string

print(string.ascii_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
ascii_letters = string.ascii_letters

# %%
def get_random_lower_case_word(max_length_of_word):

    s_length = random.randint(0, max_length_of_word)
    s        = "".join([choice(ascii_letters) for _ in range(s_length)])

    # return s.lower()
    return ("abcd" + s.lower())

# %%
def get_needle_and_haystack(max_length_of_haystack=30):

    haystack_length = random.randint(0, max_length_of_haystack)
    needle_length   = random.randint(0, haystack_length)

    haystack = get_random_lower_case_word(haystack_length)
    needle   = get_random_lower_case_word(needle_length)

    return needle, haystack

# %%
needle, haystack = get_needle_and_haystack()
print(needle, haystack)
# Out:
# abcdaev abcdcvyp

# %%
print(needle, haystack)
# Out:
# abcdaev abcdcvyp

# %% [markdown]
# ## First Print All Positions with Correct Indices

# %%
from typing import List
import pdb

class Solution:
    def strStr(self, haystack: str, needle: str) -> int:

        needle_length   = len(needle)
        haystack_length = len(haystack)

        if needle_length > haystack_length:
            return -1

        found = 0

        for i in range(0, haystack_length - needle_length + 1):
            print(f"Remaining Haystack: {haystack[i:]}")
            print(f"Remaining Needle: {needle[i:]}")

            print(f"comparing starting at index {i}")
            print("************")
            match_count = 0
            for j in range(i, i + needle_length):
                # if haystack[j] == needle[j - i]:
                #     match_count += 1
                # if match_count == needle_length:
                #     found = 1
                #     break

                print(f"Haystack at j: {j}, {haystack[j]}")
                print(f"Needle at j: {j - i}, {needle[j - i]}")
            print("************")
            print("************")

            if found == 1:
                return i

        return -1

# %% [markdown]
# ## Add If Conditions

# %%
from typing import List
import pdb

class Solution:
    def strStr(self, haystack: str, needle: str) -> int:

        needle_length   = len(needle)
        haystack_length = len(haystack)

        if needle_length > haystack_length:
            return -1

        found = 0

        for i in range(0, haystack_length - needle_length + 1):
            print(f"Remaining Haystack: {haystack[i:]}")
            print(f"Remaining Needle: {needle[i:]}")

            print(f"comparing starting at index {i}")
            print("************")
            match_count = 0
            for j in range(i, i + needle_length):
                if haystack[j] == needle[j - i]:
                    match_count += 1
                if match_count == needle_length:
                    found = 1
                    break

                print(f"Haystack at j: {j}, {haystack[j]}")
                print(f"Needle at j: {j - i}, {needle[j - i]}")
            print("************")
            print("************")

            if found == 1:
                return i

        return -1

# %% [markdown]
# ## Remove Print Statements

# %%
from typing import List
import pdb

class Solution:
    def strStr(self, haystack: str, needle: str) -> int:

        needle_length   = len(needle)
        haystack_length = len(haystack)

        if needle_length > haystack_length:
            return -1

        found = 0

        for i in range(0, haystack_length - needle_length + 1):

            match_count = 0
            for j in range(i, i + needle_length):
                if haystack[j] == needle[j - i]:
                    match_count += 1
                if match_count == needle_length:
                    found = 1
                    break
            if found == 1:
                return i

        return -1

# %%
solution_object = Solution()
string_outputs      = solution_object.strStr("abcdefghij", "ij")
# string_outputs      = solution_object.longestCommonPrefix(["a"])

print(f"{string_outputs=}")
# Out:
# Remaining Haystack: abcdefghij
# Remaining Needle: ij
# comparing starting at index 0
# ************
# Haystack at j: 0, a
# Needle at j: 0, i
# Haystack at j: 1, b
# Needle at j: 1, j
# ************
# ************
# Remaining Haystack: bcdefghij
# Remaining Needle: j
# comparing starting at index 1
# ************
# Haystack at j: 1, b
# Needle at j: 0, i
# Haystack at j: 2, c
# Needle at j: 1, j
# ************
# ************
# Remaining Haystack: cdefghij
# Remaining Needle:
# comparing starting at index 2
# ************
# Haystack at j: 2, c
# Needle at j: 0, i
# Haystack at j: 3, d
# Needle at j: 1, j
# ************
# ************
# Remaining Haystack: defghij
# Remaining Needle:
# comparing starting at index 3
# ************
# Haystack at j: 3, d
# Needle at j: 0, i
# Haystack at j: 4, e
# Needle at j: 1, j
# ************
# ************
# Remaining Haystack: efghij
# Remaining Needle:
# comparing starting at index 4
# ************
# Haystack at j: 4, e
# Needle at j: 0, i
# ...

# %%
print(len(needle))
print(len(haystack))
# Out:
# 7
# 8

# %%
from typing import List
import pdb
class Solution:
    def longestCommonPrefix(self, strs: List[str]) -> str:

        longest_common_prefix   = []
        current_char_to_compare = ""
        current_index           = -1
        exit_loop               = 0

        # pdb.set_trace()
        if len(strs) > 0:
            while (exit_loop < 1):
                current_index += 1
                if (current_index <= (len(strs[0]) - 1)):
                    current_char_to_compare = strs[0][current_index]
                else:
                    exit_loop = 1

                exit_for_loop = 0
                for str in strs[1:]:
                    if (current_index > (len(str) - 1)) or (str[current_index] != current_char_to_compare):
                        exit_for_loop = 1
                        break

                if (exit_for_loop == 0) and ((exit_loop == 0)):
                    longest_common_prefix.append(current_char_to_compare)
                else:
                    exit_loop = 1


        return "".join(longest_common_prefix)

# %%
solution_object = Solution()
string_outputs      = solution_object.longestCommonPrefix(random_word_string)
# string_outputs      = solution_object.longestCommonPrefix(["a"])

print(f"{string_outputs=}")
# Out:
# string_outputs='abcd'
